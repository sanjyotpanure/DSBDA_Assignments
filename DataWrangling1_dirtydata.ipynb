# %% [markdown]
# Loading the important libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading Dataset

# %%
data=pd.read_csv('/content/dirtydata.csv')

# %%
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
data.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
data.shape
# Out:
# (32, 5)

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  304.680000
# std     70.039591    7.832933   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.500000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %% [markdown]
# Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# Checking null values

# %%
data.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
data.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
data.count()
# Out:
# Duration    32
# Date        31
# Pulse       32
# Maxpulse    32
# Calories    30
# dtype: int64

# %%
data.count(axis='rows')
# Out:
# Duration    32
# Date        31
# Pulse       32
# Maxpulse    32
# Calories    30
# dtype: int64

# %%
print(data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# Just changing Time 450 to 45

# %%
data['Duration'][7]=45
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.head(10)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# 5        60  '2020/12/06'    102       127     300.0
# 6        60  '2020/12/07'    110       136     374.0
# 7        45  '2020/12/08'    104       134     253.3
# 8        30  '2020/12/09'    109       133     195.1
# 9        60  '2020/12/10'     98       124     269.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# Filling null values in the Calories value with the mean value of the column

# %%
data['Calories'].fillna(data['Calories'].mean(),inplace=True)

# %%
data.count()
# Out:
# Duration    32
# Date        31
# Pulse       32
# Maxpulse    32
# Calories    32
# dtype: int64

# %%
data['Calories'].mean()
# Out:
# 304.68

# %%
print(data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7         45  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
data['Calories']=data['Calories'].abs()

# %%
print(data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7         45  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %% [markdown]
# Converting Calories category into int

# %%
data['Calories']=data['Calories'].astype('int')

# %%
print(data)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130       409
# 1         60  '2020/12/02'    117       145       479
# 2         60  '2020/12/03'    103       135       340
# 3         45  '2020/12/04'    109       175       282
# 4         45  '2020/12/05'    117       148       406
# 5         60  '2020/12/06'    102       127       300
# 6         60  '2020/12/07'    110       136       374
# 7         45  '2020/12/08'    104       134       253
# 8         30  '2020/12/09'    109       133       195
# 9         60  '2020/12/10'     98       124       269
# 10        60  '2020/12/11'    103       147       329
# 11        60  '2020/12/12'    100       120       250
# 12        60  '2020/12/12'    100       120       250
# 13        60  '2020/12/13'    106       128       345
# 14        60  '2020/12/14'    104       132       379
# 15        60  '2020/12/15'     98       123       275
# ...

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
print(data)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7         45 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %% [markdown]
# Converting Date category into datetime as the to convert '20201226' to date format

# %%
data['Date']=data['Date'].astype('datetime64[D]')

# %%
print(data)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7         45 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %% [markdown]
# Dropping null values

# %%
data.dropna()
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7         45 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %%
data.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.066974 -0.258764  0.323313
# Pulse    -0.066974  1.000000  0.276583  0.487653
# Maxpulse -0.258764  0.276583  1.000000  0.347177
# Calories  0.323313  0.487653  0.347177  1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
num=list(data.select_dtypes(include=np.number).columns)
num
# Out:
# ['Duration', 'Pulse', 'Maxpulse', 'Calories']

# %%
figure = plt.figure(figsize=(10, 7))
for i in range(len(num)):
    plt.subplot(2, 2, i+1)
    sns.histplot(data[num[i]], bins=10, kde=True)
